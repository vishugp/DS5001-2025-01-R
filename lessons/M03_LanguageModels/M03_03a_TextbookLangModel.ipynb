# %% [markdown]
# # Textbook Language Model
#
# DS 5001 Text as Data
#
# **Purpose**: Demonstrates use of simple langauge model based on Berkeley restaurant data (from Jurafsky and Martin).

# %% [markdown]
# ## Set Up

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Make the Data

# %% [markdown]
# We convert these three tables into Pandas dataframes and use them to predict and generate sentences.
#
# ![](lm-data.png)

# %% [markdown]
# First, we create the table of unigrams and their frrequencies, i.e. the priors or marginals of a bigram model.
#
# Note that this counts are relative to the entire corpus, not just the subset represented in the bigram table. So, we can't compute the probabilities of the unigrams.

# %%
data1 = dict(
    w0 = "i want to eat chinese food lunch spend".split(),
    n = [2533, 927, 2417, 746, 158, 1093, 341, 278]
)

# %%
df1 = pd.DataFrame(data1).set_index(['w0'])
df1.n = df1.n.astype('int')

# %% [markdown]
# Since we will want to use unigram probabilities for our model, we will estimate the number of tokens in the corpus. We will chose $50000$, based on the data found in [The Berkeley Restaurant Project (BeRP) Transcripts](https://github.com/wooters/berp-trans/). (We sum the counts in the `wordhist.txt` file and round down, since the data in the repo contain higher word counts for our words.)

# %%
C = 50000

# %%
df1['p'] = df1.n / C
df1['i'] = np.log2(1/df1.p)

# %%
df1
# Out:
#             n        p         i
# w0
# i        2533  0.05066  4.303009
# want      927  0.01854  5.753215
# to       2417  0.04834  4.370639
# eat       746  0.01492  6.066609
# chinese   158  0.00316  8.305860
# food     1093  0.02186  5.515563
# lunch     341  0.00682  7.196013
# spend     278  0.00556  7.490699

# %% [markdown]
# Next, we create a table joint probabilities that will be the basis for our bigram model.

# %%
data2 = [row.split(", ") for row in """
i, i, 5
i, want, 837
i, eat, 9
i, spend, 2
want, i, 2
want, to, 608
want, eat, 1
want, chinese, 6
want, food, 6
want, lunch, 5
want, spend, 1
to, i, 2
to, to, 4
to, eat, 686
to, chinese, 2
to, lunch, 6
to, spend, 211
eat, to, 2
eat, chinese, 16
eat, food, 2
eat, lunch, 42
chinese, i, 1
chinese, food, 82
chinese, lunch, 1
food, i, 15
food, to, 15
food, chinese, 1
food, food, 4
lunch, i, 2
lunch, food, 1
spend, i, 1
spend, to, 1
""".split("\n")[1:-1]]

# %%
df2 = pd.DataFrame(data2, columns = ['w0', 'w1', 'n']).set_index(['w0','w1'])
df2.n = df2.n.astype('int')

# %%
df2.sort_values('n', ascending=False)
# Out:
#                    n
# w0      w1
# i       want     837
# to      eat      686
# want    to       608
# to      spend    211
# chinese food      82
# eat     lunch     42
#         chinese   16
# food    to        15
#         i         15
# i       eat        9
# want    chinese    6
#         food       6
# to      lunch      6
# i       i          5
# want    lunch      5
# food    food       4
# to      to         4
#         chinese    2
#         i          2
# eat     to         2
#         food       2
# lunch   i          2
# want    i          2
# i       spend      2
# spend   i          1
# lunch   food       1
# chinese lunch      1
# food    chinese    1
# want    eat        1
# chinese i          1
# want    spend      1
# spend   to         1

# %%
df2.unstack(fill_value=0).style.background_gradient(cmap='YlGnBu', axis=None)
# Out:
# <style  type="text/css" >
#     #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row0_col0 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row0_col1 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row0_col2 {
#             background-color:  #f1faba;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row0_col3 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row0_col4 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row0_col5 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row0_col6 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row0_col7 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row1_col0 {
#             background-color:  #fdfed4;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row1_col1 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row1_col2 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row1_col3 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row1_col4 {
#             background-color:  #f8fcca;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row1_col5 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row1_col6 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row1_col7 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row2_col0 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row2_col1 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row2_col2 {
#             background-color:  #feffd8;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row2_col3 {
#             background-color:  #fdfed4;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row2_col4 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row2_col5 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row2_col6 {
#             background-color:  #fdfed4;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row2_col7 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row3_col0 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row3_col1 {
#             background-color:  #feffd6;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row3_col2 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row3_col3 {
#             background-color:  #feffd8;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row3_col4 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row3_col5 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row3_col6 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row3_col7 {
#             background-color:  #081d58;
#             color:  #f1f1f1;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row4_col0 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row4_col1 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row4_col2 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row4_col3 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row4_col4 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row4_col5 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row4_col6 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row4_col7 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row5_col0 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row5_col1 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row5_col2 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row5_col3 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row5_col4 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row5_col5 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row5_col6 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row5_col7 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row6_col0 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row6_col1 {
#             background-color:  #24479d;
#             color:  #f1f1f1;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row6_col2 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row6_col3 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row6_col4 {
#             background-color:  #feffd8;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row6_col5 {
#             background-color:  #c6e9b4;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row6_col6 {
#             background-color:  #feffd8;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row6_col7 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row7_col0 {
#             background-color:  #feffd8;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row7_col1 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row7_col2 {
#             background-color:  #feffd8;
#             color:  #000000;
#         }    #T_4c8ea128_df3f_11ef_9252_3cfdfe7583b0row7_col3 {
#             background-color:  #ffffd9;
#             color:  #000000;

# %% [markdown]
# Next, we compute conditional probabilities $p$ with the formula $p(B|A) = \large \frac{P(A,B)}{P(A)}$ converted to $\large \frac{C(A,B)}{C(A)}$.
#
# We also compute the information $i$ for each $p$. This will allow use to compute perplexity $pp$ easily.
#
# Note that information $i$ is just the negative of the log probability of the event, so we can use this to compute the log probability of sentences later.

# %%
df2['p'] = df2.n / df1.n
df2['i'] = np.log2(1/df2.p)

# %%
df2.sort_values('p', ascending=False).style.background_gradient(cmap='YlGnBu')
# Out:
# <style  type="text/css" >
#     #T_544c9198_df46_11ef_9252_3cfdfe7583b0row0_col0 {
#             background-color:  #2168ad;
#             color:  #f1f1f1;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row0_col1 {
#             background-color:  #081d58;
#             color:  #f1f1f1;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row0_col2 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row1_col0 {
#             background-color:  #f1fabb;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row1_col1 {
#             background-color:  #2350a1;
#             color:  #f1f1f1;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row1_col2 {
#             background-color:  #fafdcf;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row2_col0 {
#             background-color:  #081d58;
#             color:  #f1f1f1;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row2_col1 {
#             background-color:  #40b5c4;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row2_col2 {
#             background-color:  #f0f9b8;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row3_col0 {
#             background-color:  #24479d;
#             color:  #f1f1f1;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row3_col1 {
#             background-color:  #63c3bf;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row3_col2 {
#             background-color:  #edf8b2;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row4_col0 {
#             background-color:  #c6e9b4;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row4_col1 {
#             background-color:  #ecf7b1;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row4_col2 {
#             background-color:  #abdeb7;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row5_col0 {
#             background-color:  #f8fcca;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row5_col1 {
#             background-color:  #f3fabf;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row5_col2 {
#             background-color:  #85cfba;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row6_col0 {
#             background-color:  #fdfed4;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row6_col1 {
#             background-color:  #fafdcf;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row6_col2 {
#             background-color:  #3eb3c4;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row7_col0 {
#             background-color:  #fdfed4;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row7_col1 {
#             background-color:  #fcfed3;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row7_col2 {
#             background-color:  #2b9fc2;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row8_col0 {
#             background-color:  #fdfed4;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row8_col1 {
#             background-color:  #fcfed3;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row8_col2 {
#             background-color:  #2b9fc2;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row9_col0 {
#             background-color:  #feffd8;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row9_col1 {
#             background-color:  #feffd6;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row9_col2 {
#             background-color:  #1f78b4;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row10_col0 {
#             background-color:  #feffd8;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row10_col1 {
#             background-color:  #feffd6;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row10_col2 {
#             background-color:  #1f78b4;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row11_col0 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row11_col1 {
#             background-color:  #feffd6;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row11_col2 {
#             background-color:  #2076b3;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row12_col0 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row12_col1 {
#             background-color:  #feffd6;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row12_col2 {
#             background-color:  #2076b3;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row13_col0 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row13_col1 {
#             background-color:  #feffd8;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row13_col2 {
#             background-color:  #2072b1;
#             color:  #f1f1f1;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row14_col0 {
#             background-color:  #feffd8;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row14_col1 {
#             background-color:  #feffd8;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row14_col2 {
#             background-color:  #216daf;
#             color:  #f1f1f1;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row15_col0 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row15_col1 {
#             background-color:  #feffd8;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row15_col2 {
#             background-color:  #2356a4;
#             color:  #f1f1f1;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row16_col0 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row16_col1 {
#             background-color:  #feffd8;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row16_col2 {
#             background-color:  #2355a4;
#             color:  #f1f1f1;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row17_col0 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row17_col1 {
#             background-color:  #feffd8;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row17_col2 {
#             background-color:  #2355a4;
#             color:  #f1f1f1;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row18_col0 {
#             background-color:  #feffd6;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row18_col1 {
#             background-color:  #feffd8;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row18_col2 {
#             background-color:  #2355a4;
#             color:  #f1f1f1;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row19_col0 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row19_col1 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_544c9198_df46_11ef_9252_3cfdfe7583b0row19_col2 {
#             background-color:  #234b9f;

# %% [markdown]
# We convert a selection from the narrow table into a wide one, projecting the second index feature `w1` onto the second axis.
#
# This is strictly not necessary, but it is convenient for certain computations and it is visually appealing.

# %%
df3 = df2.p.unstack(fill_value=0)

# %%
df3.style.background_gradient(cmap='YlGnBu', axis=None)
# Out:
# <style  type="text/css" >
#     #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row0_col0 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row0_col1 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row0_col2 {
#             background-color:  #2350a1;
#             color:  #f1f1f1;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row0_col3 {
#             background-color:  #feffd6;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row0_col4 {
#             background-color:  #feffd6;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row0_col5 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row0_col6 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row0_col7 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row1_col0 {
#             background-color:  #fafdcf;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row1_col1 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row1_col2 {
#             background-color:  #feffd8;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row1_col3 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row1_col4 {
#             background-color:  #f3fabf;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row1_col5 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row1_col6 {
#             background-color:  #feffd8;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row1_col7 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row2_col0 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row2_col1 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row2_col2 {
#             background-color:  #feffd8;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row2_col3 {
#             background-color:  #fcfed3;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row2_col4 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row2_col5 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row2_col6 {
#             background-color:  #fcfed3;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row2_col7 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row3_col0 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row3_col1 {
#             background-color:  #feffd8;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row3_col2 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row3_col3 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row3_col4 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row3_col5 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row3_col6 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row3_col7 {
#             background-color:  #40b5c4;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row4_col0 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row4_col1 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row4_col2 {
#             background-color:  #feffd8;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row4_col3 {
#             background-color:  #feffd6;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row4_col4 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row4_col5 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row4_col6 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row4_col7 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row5_col0 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row5_col1 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row5_col2 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row5_col3 {
#             background-color:  #feffd8;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row5_col4 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row5_col5 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row5_col6 {
#             background-color:  #feffd8;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row5_col7 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row6_col0 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row6_col1 {
#             background-color:  #63c3bf;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row6_col2 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row6_col3 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row6_col4 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row6_col5 {
#             background-color:  #eaf7b1;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row6_col6 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row6_col7 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row7_col0 {
#             background-color:  #feffd6;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row7_col1 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row7_col2 {
#             background-color:  #feffd6;
#             color:  #000000;
#         }    #T_4cabe17a_df3f_11ef_9252_3cfdfe7583b0row7_col3 {
#             background-color:  #ffffd9;
#             color:  #000000;

# %% [markdown]
# ## Apply the Model
#
# Now we generate sentences from the model and also compute their probabilities and perplexities.
#
# We also demonstrate the relationship between sum of log probability, mean information, and perplexity.

# %%
N = 20 # N sentences
M = 5 # M tokens per sentence
results = []

# Generate N sentences
for i in range(N):
    
    # Get a start word from the unigram list (since we don't have sentence boundaries in our bigram model
    start = df1.sample(weights='n')
    w0 = start.index[0]
    i = start.i.values[0] # This is why we needed to estimate the number of tokens in the corpus C
    
    # Initialize sentence feature lists
    W = [w0]   # Tokens
    I = [i]    # information
    LP = [-i]  # log prob
    
    # Select M words for each sentence
    for j in range(M - 1):
        w1 = df3.loc[w0].sample(weights=df3.loc[w0].values).index[0]
        i = df2.loc[(w0, w1), 'i']
        W.append(w1)
        I.append(i)
        LP.append(-i)
        w0 = w1

    # Compute sentence stats
    S = pd.DataFrame(dict(w=W, i=I, lp=LP)) # This is expensive; we'd do it differently at scale
    i_mean = S.i.mean()
    lp_sum = S.lp.sum()
    pp = 2**(i_mean)
    sent_str = ' '.join(W)
    
    # Append to results 
    results.append((sent_str, lp_sum, i_mean, pp))
    
# Put results in a dataframe
R = pd.DataFrame(results, columns=['sentence', 'logprob', 'i_mean', 'pp'])

# Keep only unique sentences, i.e. treat sentences as index values
sentence_counts = R.sentence.value_counts().to_frame('n')
R = R.drop_duplicates()
R = R.reset_index(drop=True).set_index('sentence')
R['n'] = sentence_counts

# Display results
R.sort_values('i_mean', ascending=True).style.background_gradient(cmap="YlGnBu")
# Out:
# <style  type="text/css" >
#     #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row0_col0 {
#             background-color:  #081d58;
#             color:  #f1f1f1;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row0_col1 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row0_col2 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row0_col3 {
#             background-color:  #081d58;
#             color:  #f1f1f1;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row1_col0 {
#             background-color:  #234c9f;
#             color:  #f1f1f1;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row1_col1 {
#             background-color:  #d7efb3;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row1_col2 {
#             background-color:  #f6fbc5;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row1_col3 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row2_col0 {
#             background-color:  #2165ab;
#             color:  #f1f1f1;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row2_col1 {
#             background-color:  #bde5b5;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row2_col2 {
#             background-color:  #f1fabb;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row2_col3 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row3_col0 {
#             background-color:  #1e85ba;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row3_col1 {
#             background-color:  #90d4b9;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row3_col2 {
#             background-color:  #e9f7b1;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row3_col3 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row4_col0 {
#             background-color:  #1e86bb;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row4_col1 {
#             background-color:  #8ed3ba;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row4_col2 {
#             background-color:  #e9f7b1;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row4_col3 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row5_col0 {
#             background-color:  #1d91c0;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row5_col1 {
#             background-color:  #7ecdbb;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row5_col2 {
#             background-color:  #e5f5b2;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row5_col3 {
#             background-color:  #97d6b9;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row6_col0 {
#             background-color:  #2195c0;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row6_col1 {
#             background-color:  #78cbbc;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row6_col2 {
#             background-color:  #e1f3b2;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row6_col3 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row7_col0 {
#             background-color:  #2a9ec1;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row7_col1 {
#             background-color:  #69c5be;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row7_col2 {
#             background-color:  #dbf1b2;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row7_col3 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row8_col0 {
#             background-color:  #2ea3c2;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row8_col1 {
#             background-color:  #61c2bf;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row8_col2 {
#             background-color:  #d9f0b3;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row8_col3 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row9_col0 {
#             background-color:  #3bb0c3;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row9_col1 {
#             background-color:  #4cbac2;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row9_col2 {
#             background-color:  #ceecb3;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row9_col3 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row10_col0 {
#             background-color:  #44b7c4;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row10_col1 {
#             background-color:  #3fb4c4;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row10_col2 {
#             background-color:  #c8e9b4;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row10_col3 {
#             background-color:  #97d6b9;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row11_col0 {
#             background-color:  #caeab4;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row11_col1 {
#             background-color:  #225aa6;
#             color:  #f1f1f1;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row11_col2 {
#             background-color:  #37acc3;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row11_col3 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row12_col0 {
#             background-color:  #cfecb3;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row12_col1 {
#             background-color:  #2355a4;
#             color:  #f1f1f1;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row12_col2 {
#             background-color:  #32a6c2;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row12_col3 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row13_col0 {
#             background-color:  #e6f5b2;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row13_col1 {
#             background-color:  #243c98;
#             color:  #f1f1f1;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row13_col2 {
#             background-color:  #1f7ab5;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row13_col3 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row14_col0 {
#             background-color:  #ffffd9;
#             color:  #000000;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row14_col1 {
#             background-color:  #081d58;
#             color:  #f1f1f1;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row14_col2 {
#             background-color:  #081d58;
#             color:  #f1f1f1;
#         }    #T_56c149c8_df46_11ef_9252_3cfdfe7583b0row14_col3 {
#             background-color:  #ffffd9;

# %% [markdown]
# ## Interpet Results

# %% [markdown]
# Compare mean `i` to the sum of log `p`. Notice they are identical when normalized by mean.

# %%
(R / R.mean()).sort_values('i_mean')[['i_mean','logprob']].reset_index().plot();

# %% [markdown]
# Compre perplexity `pp` to mean information `i`. Notice how perplexity amplifies the difference.

# %%
(R / R.mean()).sort_values('i_mean')[['i_mean','pp']].reset_index().plot();

# %% [markdown]
# So, we will use perplexity to measure of how well a model performs.

# %%
R.reset_index().set_index('sentence').sort_values('pp').i_mean.sort_values(ascending=False)\
    .plot.barh(figsize=(7,7), title="Generated Sentences Sorted by Perplexity");

# %% [markdown]
# Since perplexity looks something like squaring the error of our model\
# (where mean information is interpreted as error), let's create a test \
# feature that just squares mean information and compare to the other features.

# %%
R['test'] = R.i_mean**2

# %%
(R / R.mean()).sort_values('i_mean')[['i_mean', 'test','pp']].reset_index().plot();
