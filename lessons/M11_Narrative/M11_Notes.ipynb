# %% [markdown]
# # M11 Notes

# %% [markdown]
# ## Installing the R Kernel for Jupyter
#
# Here's a [How To](M11_00_Rkernel.ipynb).

# %% [markdown]
# ## Topology

# %% [markdown]
# ![image.png](attachment:122afb3b-c9fb-447c-be10-73514fbe16ea.png)
#
# > The traditional joke about topologists is that they can't tell \
# the difference between a coffee mug and a doughnut. \
# &mdash; [Source](https://www.shapeways.com/product/6CJQ9GXWW/topology-joke).
#
# See also these articles from Phys.org:
# - [When is a coffee mug a donut? Topology explains it](https://phys.org/news/2016-10-coffee-donut-topology.html)
# - [Nobel physics prize awarded to three for topology work (Update 6)](https://phys.org/news/2016-10-nobel-physics-prize-awarded-topology.html)
#
# Now, get this:
#
# > Topology is geometry without lines, and algebra without operations. \
# It's fundamental to our concept of space, and **gives formal structure to blobs.** \
# &mdash; From the London Maths Outreach [page on YouTube](https://www.youtube.com/playlist?app=desktop&list=PLzmwKdSpxg2D2PCHclNmbc-y_2Gw0ODk7).
#
# It may be that topology may help us understand what we do with data in data science.
#
# We do a lot of reshaping.

# %% [markdown]
# # TextBlob
#
# Now, consider this text processing library called [TextBlob](https://github.com/sloria/TextBlob).
#
# ![image.png](attachment:f642f30c-e08b-4850-9698-5eda1bb3c035.png)
#
# This a fun coincidence&mdash;the link between topology and text&mdash;but it offers insight into what we do in text analytics.
#
# In fact, there is a body of literature on the subject:
#
# - [Trees and After: The Concept of Text Topology. Some Applications to Verb-Form Distributions in Language Corpora](https://academic.oup.com/dsh/article/22/2/167/940444)
# - [Plot Holes and Text Topology](https://web.stanford.edu/class/archive/cs/cs224n/cs224n.1204/reports/custom/report46.pdf)

# %% [markdown]
# # Plot Structure with Topic Models
#
# Ben Schmidt has fun paper on mapping plots over time with topic models:
# https://sappingattention.blogspot.com/2014/12/typical-tv-episodes-visualizing-topics.html

# %% [markdown]
# # About Sentiment Signals
#
# Think of the ordering of words as a rhetorical practice, with the goal leading the reader into an emotional reponse.
#
# Let the telling of a joke -- timing is everthing.
#
# It's a signal because it is a time-series of events.
#
# > Time-series data is a subset of signals where measurements are recorded at successive points in time. Signals can be either analog (continuous) or digital (discrete).\
# &mdash; from [A Data Scientist's Guide to Signal Processing](https://www.datacamp.com/tutorial/a-data-scientists-guide-to-signal-processing)
