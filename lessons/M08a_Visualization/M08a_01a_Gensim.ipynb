# %% [markdown]
# # LDA with Gensim
#
# ```yaml
# Course:    DS 5001
# Module:    08 Lab
# Topic:     LDA with Gensim
# Author:    R.C. Alvarado
# Date:      05 March 2024
# ```
#
# **Purpose:** Using Gensim to generate topic models.

# %% [markdown]
# # Set Up

# %% [markdown]
# ## Config

# %%
import configparser
config = configparser.ConfigParser()
config.read('../../../env.ini')
data_home = config['DEFAULT']['data_home']
output_dir = config['DEFAULT']['output_dir']
local_lib = config['DEFAULT']['local_lib']

# %%
data_prefix = 'austen-melville'

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
from gensim.corpora import Dictionary
from gensim.models import LdaModel

# %% [markdown]
# # Get Data

# %%
TOKENS = pd.read_csv(f"{output_dir}/{data_prefix}-TOKEN.csv")
OHCO = list(TOKENS.columns[:5])
TOKENS = TOKENS.set_index(OHCO)

# %% [markdown]
# # Create Gensum Corpus

# %% [markdown]
# We convert our TOKENS table into Gensim data structures.
#
# Gensim uses lists and dictionaries wrapped in objects to provide various kinds of access.
#
# Note that this is a bit of reinventing the wheel and it's not faster than what we've been doing with Pandas.

# %%
TOKENS['pos_group'] = TOKENS.pos.str[:2]

# %%
CORPUS = TOKENS[TOKENS.pos_group.str.contains('NN|VB') & ~TOKENS.pos.str.contains('NNP')]

# %%
DOCS = CORPUS.dropna().groupby(OHCO[:3]).term_str.apply(list)

# %%
DOCS
# Out:
# book_id  chap_num  para_num
# 105      1         1           [was, man, who, amusement, took, book, found, ...
#                    2                                                    [elliot]
#                    3           [walter, born, married, daughter, county, lady...
#                    4           [had, paragraph, stood, printers, hands, had, ...
#                    5           [followed, history, rise, ancient, family, ter...
#                                                      ...
# 53861    15        20          [innate, disdain, bred, seamen, gees, receives...
#                    21          [is, work, be, gees, stand, round, sulks, here...
#                    22          [intellect, has, been, cultivated, well, attes...
#                    23          [account, perhaps, ethnologists, raise, curios...
#                    24          [sketchy, view, gee, information, apply, whali...
# Name: term_str, Length: 30336, dtype: object

# %%
vocab = Dictionary(DOCS.tolist()) 
vocab.filter_extremes(no_below=20, no_above=0.5)
corpus = [vocab.doc2bow(doc) for doc in DOCS.tolist()]

# %% [markdown]
# # Generate LDA
#
# Next, we train a model using Gensim's LDA topic modeler.

# %% [markdown]
# We set some training parameters.

# %% [markdown]
# Regarding these, here are some notes from the Gensim site:
#
# > First of all, the elephant in the room: how many topics do I need? There is
# really no easy answer for this, it will depend on both your data and your
# application. I have used 10 topics here because I wanted to have a few topics
# that I could interpret and "label", and because that turned out to give me
# reasonably good results. You might not need to interpret all your topics, so
# you could use a large number of topics, for example 100.
#
# > ``chunksize`` controls how many documents are processed at a time in the
# training algorithm. Increasing chunksize will speed up training, at least as
# long as the chunk of documents easily fit into memory. I've set ``chunksize =
# 2000``, which is more than the amount of documents, so I process all the
# data in one go. Chunksize can however influence the quality of the model, as
# discussed in Hoffman and co-authors [2], but the difference was not
# substantial in this case.
#
# > ``passes`` controls how often we train the model on the entire corpus.
# Another word for passes might be "epochs". ``iterations`` is somewhat
# technical, but essentially it controls how often we repeat a particular loop
# over each document. It is important to set the number of "passes" and
# "iterations" high enough.
#
# > I suggest the following way to choose iterations and passes. First, enable
# logging (as described in many Gensim tutorials), and set ``eval_every = 1``
# in ``LdaModel``. When training the model look for a line in the log that
# looks something like this::
#
# >```2016-06-21 15:40:06,753 - gensim.models.ldamodel - DEBUG - 68/1566 documents converged within 400 iterations```
#
# > If you set ``passes = 20`` you will see this line 20 times. Make sure that by
# the final passes, most of the documents have converged. So you want to choose
# both passes and iterations to be high enough for this to happen.
#
# > We set ``alpha = 'auto'`` and ``eta = 'auto'``. Again this is somewhat
# technical, but essentially we are automatically learning two parameters in
# the model that we usually would have to specify explicitly.

# %%
num_topics = 40
chunksize = 2000
passes = 20
iterations = 400
eval_every = None  # Don't evaluate model perplexity, takes too much time.

# %% [markdown]
# We also make an index to word dictionary, since the model wants it.

# %%
temp = vocab[0]  # This is only to "load" the dictionary.
id2word = vocab.id2token

# %%
model = LdaModel(
    corpus=corpus,
    id2word=id2word,
    chunksize=chunksize,
    alpha='auto',
    eta='auto',
    iterations=iterations,
    num_topics=num_topics,
    passes=passes,
    eval_every=eval_every
)

# %% [markdown]
# # Inspect Results

# %%
PHI_gs = pd.DataFrame(model.get_topics(), columns=[v[1] for v in vocab.items()])

# %%
THETA_gs = pd.DataFrame([(i, t[0], t[1]) 
    for i, d in enumerate(model.get_document_topics(corpus)) 
    for t in d],
    columns=['doc_id', 'topic_id', 'topic_weight'])\
    .set_index(['doc_id','topic_id'])\
    .unstack(fill_value=0)
THETA_gs.index = DOCS.index
THETA_gs.columns = THETA_gs.columns.droplevel(0)

# %%
THETA_gs
# Out:
# topic_id                         0    1         2    3         4         5   \
# book_id chap_num para_num
# 105     1        1         0.000000  0.0  0.000000  0.0  0.000000  0.050855
#                  2         0.016345  0.0  0.017052  0.0  0.000000  0.000000
#                  3         0.012350  0.0  0.012884  0.0  0.030006  0.000000
#                  4         0.010123  0.0  0.010561  0.0  0.044652  0.000000
#                  5         0.000000  0.0  0.000000  0.0  0.022342  0.000000
# ...                             ...  ...       ...  ...       ...       ...
# 53861   15       20        0.000000  0.0  0.000000  0.0  0.000000  0.000000
#                  21        0.045633  0.0  0.000000  0.0  0.000000  0.000000
#                  22        0.000000  0.0  0.041499  0.0  0.020179  0.000000
#                  23        0.069424  0.0  0.000000  0.0  0.000000  0.000000
#                  24        0.013326  0.0  0.013903  0.0  0.058824  0.000000
#
# topic_id                         6         7         8         9   ...  \
# book_id chap_num para_num                                          ...
# 105     1        1         0.021893  0.019760  0.021575  0.020186  ...
#                  2         0.013623  0.000000  0.012969  0.010024  ...
#                  3         0.010293  0.000000  0.000000  0.000000  ...
#                  4         0.000000  0.000000  0.000000  0.000000  ...
#                  5         0.025881  0.000000  0.000000  0.000000  ...
# ...                             ...       ...       ...       ...  ...
# 53861   15       20        0.000000  0.021424  0.000000  0.000000  ...
#                  21        0.000000  0.000000  0.000000  0.000000  ...
#                  22        0.000000  0.000000  0.000000  0.000000  ...
#                  23        0.021896  0.000000  0.036995  0.000000  ...
#                  24        0.011107  0.000000  0.010574  0.000000  ...
#
# topic_id                         30        31        32        33        34  \
# book_id chap_num para_num
# 105     1        1         0.000000  0.040857  0.000000  0.000000  0.000000
#                  2         0.000000  0.021053  0.000000  0.011279  0.015835
#                  3         0.031551  0.015907  0.000000  0.000000  0.011964
#                  4         0.000000  0.013039  0.000000  0.000000  0.000000
#                  5         0.000000  0.048272  0.000000  0.000000  0.000000
# ...                             ...       ...       ...       ...       ...
# 53861   15       20        0.000000  0.027546  0.020074  0.000000  0.024838
#                  21        0.000000  0.011849  0.000000  0.000000  0.000000
#                  22        0.000000  0.010683  0.000000  0.022133  0.000000
#                  23        0.000000  0.010024  0.000000  0.000000  0.000000
#                  24        0.000000  0.017165  0.000000  0.000000  0.012910
#
# topic_id                         35        36        37   38        39
# book_id chap_num para_num
# 105     1        1         0.014171  0.000000  0.000000  0.0  0.350516
#                  2         0.028965  0.014839  0.012293  0.0  0.336437
#                  3         0.021885  0.011212  0.000000  0.0  0.303046
#                  4         0.037982  0.000000  0.027658  0.0  0.368667
#                  5         0.034516  0.026573  0.000000  0.0  0.332426
# ...                             ...       ...       ...  ...       ...
# 53861   15       20        0.014943  0.000000  0.000000  0.0  0.302017
#                  21        0.016357  0.000000  0.000000  0.0  0.249048
#                  22        0.014698  0.000000  0.000000  0.0  0.388021
#                  23        0.030056  0.000000  0.021250  0.0  0.270093
#                  24        0.023615  0.012099  0.010023  0.0  0.353290
#
# [30336 rows x 40 columns]

# %%
THETA_gs.iloc[7].plot.bar(rot=45, figsize=(10,5));

# %% [markdown]
# # Topic Coherence
#
# Topic coherence measures **the degree of semantic similarity between high-scoring words in the topic**.
# - These measures help in distinguishing between topics that are semantically interpretable and topics that are artifacts of the statistical model.
# - A coherent topic will have high-scoring words that are semantically related, indicating that the topic is likely to be meaningful.
#
# UMass topic coherence is based on document co-occurrence frequencies. A high score suggests that the top words in a topic frequently occur together in
# documents.
#
# **QUESTION: Does co-ocurrence imply semantic similarity?**
#
# More info from the docs:
#
# > We can compute the topic coherence of each topic. Below we display the
# average topic coherence and print the topics in order of topic coherence.
# >
# > Note that we use the "Umass" topic coherence measure here (see
# `gensim.models.ldamodel.LdaModel.top_topics`), Gensim has recently
# obtained an implementation of the "AKSW" topic coherence measure (see
# accompanying blog post, http://rare-technologies.com/what-is-topic-coherence/).
# >
# > If you are familiar with the subject of the articles in this dataset, you can
# see that the topics below make a lot of sense. However, they are not without
# flaws. We can see that there is substantial overlap between some topics,
# others are hard to interpret, and most of them have at least some terms that
# seem out of place. If you were able to do better, feel free to share your
# methods on the blog at http://rare-technologies.com/lda-training-tips/ !

# %%
top_topics = model.top_topics(corpus)

# %% [markdown]
# Average topic coherence is the sum of topic coherences of all topics, divided by the number of topics.

# %%
top_topics
# Out:
# [([(0.099659935, 'was'),
#    (0.050770473, 'had'),
#    (0.033741947, 'were'),
#    (0.02532709, 'be'),
#    (0.022803549, 'been'),
#    (0.017786002, 'him'),
#    (0.014812496, 'time'),
#    (0.013244778, 'did'),
#    (0.013036704, 'being'),
#    (0.01260937, 'have'),
#    (0.010745775, 'seemed'),
#    (0.010202916, 'made'),
#    (0.008995188, 'thought'),
#    (0.0076739276, 'and'),
#    (0.0074442625, 'sort'),
#    (0.00734821, 'them'),
#    (0.006709377, 'way'),
#    (0.006642404, 'heart'),
#    (0.006622573, 'nothing'),
#    (0.0065177004, 'life')],
#   -2.1735555371823447),
#  ([(0.16189377, 'is'),
#    (0.08374854, 'be'),
#    (0.06630276, 'have'),
#    (0.065026514, 'are'),
#    (0.050110728, 'man'),
#    (0.039228268, 'it'),
#    (0.037698865, 'do'),
#    (0.025741154, 'has'),
#    (0.024390336, 'say'),
#    (0.020724729, 'know'),
#    (0.020608386, 'men'),
#    (0.017897768, 'come'),
#    (0.017645022, 'world'),
#    (0.017311497, 'think'),
#    (0.016703619, 'thing'),
#    (0.01571617, 'take'),
#    (0.015467306, 'that'),
#    (0.011392257, 'this'),
#    (0.01118556, 'look'),
#    (0.010046618, 'put')],
#   -2.3946593485390104),
#  ([(0.0748211, 'day'),
#    (0.052396577, 'came'),
#    (0.036483232, 'went'),
#    (0.03531658, 'morning'),
#    (0.028814202, 'till'),
#    (0.026874775, 'days'),
#    (0.021239255, 'home'),
#    (0.020880533, 'country'),
#    (0.018251492, 'coming'),
#    (0.01626899, 'return'),
#    (0.014987023, 'hours'),
#    (0.014162875, 'hour'),
#    (0.013922499, 'children'),
#    (0.013496817, 'evening'),
#    (0.013183017, 'stay'),
#    (0.013163362, 'concerning'),
#    (0.011572697, 'town'),
#    (0.011368401, 'party'),
#    (0.011353336, 'house'),
#    (0.010457693, 'visit')],
#   -3.1380696616543746),
#  ([(0.058450706, 'room'),
#    (0.045290973, 'looking'),
#    (0.041746337, 'stood'),
#    (0.035275918, 'door'),
#    (0.028897062, 'sat'),
#    (0.025988694, 'table'),
#    (0.023662059, 'chimney'),
#    (0.022850802, 'down'),
#    (0.02209015, 'bed'),
#    (0.019253738, 'arm'),
#    (0.018300202, 'ground'),
#    (0.01827151, 'when'),
#    (0.016943395, 'street'),
#    (0.016634133, 'side'),
#    (0.01649434, 'entered'),
#    (0.014699183, 'glass'),
#    (0.014014982, 'glance'),
#    (0.013628339, 'sit'),
#    (0.013374768, 'holding'),
#    (0.013158178, 'drawing')],
#   -3.979811455020035),
#  ([(0.037639864, 'fell'),
#    (0.03318962, 'back'),
#    (0.027651673, 'hair'),
#    (0.026089968, 'wind'),
#    (0.024862843, 'art'),
#    (0.024682842, 'length'),
#    (0.024046132, 'cut'),
#    (0.02358791, 'sound'),
#    (0.02136531, 'cant'),
#    (0.020651184, 'fall'),
#    (0.01983008, 'passage'),
#    (0.019624012, 'caught'),
#    (0.018447937, 'number'),
#    (0.017889192, 'ear'),
#    (0.015750505, 'filled'),
#    (0.0150869945, 'seized'),
#    (0.012440262, 'presented'),
#    (0.012277954, 'below'),
#    (0.012014731, 'houses'),
#    (0.011795785, 'raised')],
#   -5.761031348191474),
#  ([(0.12150271, 'head'),
#    (0.11551052, 'air'),
#    (0.10143314, 'face'),
#    (0.08891013, 'looked'),
#    (0.04098392, 'last'),
#    (0.037622523, 'hat'),
#    (0.03086861, 'gentlemen'),
#    (0.029676305, 'heads'),
#    (0.026993262, 'ran'),
#    (0.025433565, 'chamber'),
#    (0.02233698, 'blue'),
#    (0.0213214, 'lying'),
#    (0.021125153, 'dress'),
#    (0.02063631, 'hall'),
#    (0.016722614, 'burst'),
#    (0.015508909, 'figure'),
#    (0.014903706, 'groves'),
#    (0.01436775, 'about'),
#    (0.012373435, 'seas'),
#    (0.012053204, 'laughed')],
#   -6.252651043680222),
#  ([(0.18314189, 'sea'),
#    (0.16988881, 'round'),
#    (0.12053715, 'water'),
#    (0.056272037, 'stranger'),
#    (0.045712873, 'line'),
#    (0.03664997, 'spot'),
#    (0.034307234, 'trees'),
#    (0.03173203, 'horse'),
#    (0.024483515, 'my'),
#    (0.021861192, 'places'),
#    (0.018614283, 'falling'),
#    (0.017566819, 'pointing'),
#    (0.017078253, 'bay'),
#    (0.015740296, 'sweet'),
#    (0.015334981, 'rock'),
#    (0.014143548, 'since'),
#    (0.012658324, 'rocks'),
#    (0.012283919, 'poured'),
#    (0.012167699, 'bearing'),
#    (0.011558435, 'tide')],
#   -7.258233869636683),
#  ([(0.07937254, 'years'),
#    (0.07518197, 'wife'),
#    (0.064745456, 'work'),
#    (0.026813792, 'age'),
#    (0.02597222, 'city'),
#    (0.02351767, 'purpose'),
#    (0.022215605, 'carried'),
#    (0.021256529, 'owing'),
#    (0.01982432, 'portrait'),
#    (0.018327605, 'brow'),
#    (0.01760961, 'thousand'),
#    (0.01715405, 'dream'),
#    (0.016622618, 'twenty'),
#    (0.016578283, 'smoke'),
#    (0.014000643, 'church'),
#    (0.013415917, 'clothes'),
#    (0.013331838, 'yards'),
#    (0.011957292, 'swept'),
#    (0.011233726, 'benefit'),
#    (0.010099125, 'married')],
#   -7.4517681320826386),
#  ([(0.11120671, 'so'),
#    (0.11007135, 'but'),
#    (0.10564951, 'tell'),
#    (0.08046926, 'well'),
#    (0.068323575, 'not'),
#    (0.06351192, 'hear'),
#    (0.06205134, 'he'),
#    (0.05520233, 'voice'),
#    (0.049068443, 'suppose'),
#    (0.04287347, 'talk'),
#    (0.04067599, 'like'),
#    (0.037356894, 'genius'),
#    (0.020691568, 'judge'),
#    (0.017005736, 'smile'),
#    (0.015153744, 'quick'),
#    (0.013921119, 'hard'),
#    (0.008107856, 'pen'),
#    (0.008013617, 'glanced'),
#    (0.007401455, 'visiting'),
#    (0.007352242, 'pausing')],
#   -7.65322450645718),
#  ([(0.15074414, 'night'),
#    (0.121833116, 'going'),
#    (0.09491372, 'get'),
#    (0.09218603, 'no'),
#    (0.05491917, 'away'),
#    (0.042218294, 'walk'),
#    (0.028861893, 'stop'),
#    (0.02366051, 'drink'),
#    (0.023482043, 'yard'),
#    (0.02345953, 'fellows'),
#    (0.022947373, 'putting'),
#    (0.022622356, 'ay'),
#    (0.020774513, 'send'),
#    (0.018552305, 'hole'),
#    (0.017186627, 'leg'),
#    (0.016316595, 'mess'),
#    (0.014394044, 'wet'),
#    (0.01192669, 'dropping'),
#    (0.011849066, 'nights'),
#    (0.011612524, 'presently')],
#   -7.914955755401625),
#  ([(0.07161722, 'sight'),
#    (0.03595489, 'plain'),
#    (0.035106685, 'earth'),
#    (0.034549296, 'foot'),
#    (0.034260333, 'rose'),
#    (0.025841566, 'distance'),
#    (0.023789331, 'road'),
#    (0.022384822, 'top'),
#    (0.02201158, 'field'),
#    (0.019964589, 'cross'),
#    (0.018610148, 'rising'),
#    (0.017736645, 'needs'),
#    (0.0166151, 'draw'),
#    (0.016108751, 'river'),
#    (0.01573529, 'lips'),
#    (0.015631454, 'gained'),
#    (0.015152843, 'mob'),
#    (0.014503143, 'fly'),
#    (0.013673188, 'gazing'),
#    (0.013095789, 'brain')],
#   -8.09521855052045),
#  ([(0.18102859, 'hand'),
#    (0.106799155, 'eye'),
#    (0.068660036, 'lay'),
#    (0.031772465, 'mystery'),
#    (0.023678256, 'play'),
#    (0.022260169, 'throwing'),
#    (0.021485573, 'wisdom'),
#    (0.021118024, 'summer'),
#    (0.021084191, 'mountains'),
#    (0.019403186, 'changed'),
#    (0.01698852, 'storm'),
#    (0.016336558, 'forty'),
#    (0.015857298, 'sky'),
#    (0.015688375, 'proceed'),
#    (0.015503341, 'advancing'),
#    (0.013983498, 'catch'),
#    (0.0133748045, 'likewise'),
#    (0.013044941, 'sheet'),
#    (0.012636071, 'rise'),
#    (0.012619001, 'powder')],
#   -8.148259501408484),
#  ([(0.057583723, 'hands'),
#    (0.027599154, 'held'),
#    (0.024598276, 'forth'),
#    (0.018214332, 'self'),
#    (0.01573209, 'shot'),
#    (0.015069385, 'peace'),
#    (0.014225233, 'mark'),
#    (0.012604848, 'whence'),
#    (0.012379833, 'touch'),
#    (0.01147968, 'rolled'),
#    (0.010730067, 'possessed'),
#    (0.01046576, 'food'),
#    (0.0104264, 'doubtless'),
#    (0.010275834, 'minds'),
#    (0.0095943725, 'pointed'),
#    (0.009467742, 'guns'),
#    (0.009451518, 'showed'),
#    (0.0093918145, 'roll'),
#    (0.009391189, 'possession'),
#    (0.009353026, 'blessed')],
#   -8.149597798385937),
#  ([(0.16289943, 'ship'),
#    (0.09567139, 'uncle'),
#    (0.079128854, 'land'),
#    (0.0557154, 'comes'),
#    (0.03800271, 'says'),
#    (0.03694449, 'what'),
#    (0.03550545, 'remember'),
#    (0.035399526, 'ones'),
#    (0.032995015, 'carry'),
#    (0.032667775, 'leaves'),
#    (0.030762572, 'touching'),
#    (0.028207835, 'mood'),
#    (0.025146268, 'hills'),
#    (0.024952646, 'calm'),
#    (0.02267157, 'ears'),
#    (0.018945245, 'advance'),
#    (0.014522479, 'must'),
#    (0.013452866, 'gale'),
#    (0.012921688, 'stick'),
#    (0.012815972, 'breaking')],
#   -8.231361149667597),
#  ([(0.122926235, 'word'),
#    (0.08914843, 'gentleman'),
#    (0.06873707, 'turn'),
#    (0.06792531, 'on'),
#    (0.061040446, 'right'),
#    (0.051138494, 'the'),
#    (0.04984464, 'fear'),
#    (0.038364973, 'his'),
#    (0.03028316, 'save'),
#    (0.027312692, 'breath'),
#    (0.025380244, 'pardon'),
#    (0.0246233, 'where'),
#    (0.022217963, 'oclock'),
#    (0.019610353, 'image'),
#    (0.017754339, 'comprehend'),
#    (0.016761536, 'much'),
#    (0.01555828, 'garden'),
#    (0.01527445, 'wrote'),
#    (0.014108172, 'beg'),
#    (0.014031825, 'deny')],
#   -8.29996534482088),
#  ([(0.36719102, 'said'),
#    (0.13189371, 'am'),
#    (0.11797288, 'i'),
#    (0.110523544, 'sir'),
#    (0.051634494, 'yes'),
#    (0.032695867, 'turning'),
#    (0.026704501, 'replied'),
#    (0.023600826, 'wish'),
#    (0.02228648, 'want'),
#    (0.017717676, 'pray'),
#    (0.013755126, 'very'),
#    (0.011941242, 'please'),
#    (0.011761179, 'they'),
#    (0.011746427, 'write'),
#    (0.0076235672, 'mistake'),
#    (0.007089454, 'song'),
#    (0.006572398, 'hide'),
#    (0.0059072273, 'sing'),
#    (0.0036215866, 'pretend'),
#    (0.002451759, 'performed')],
#   -8.381973280543116),
#  ([(0.10455885, 'stand'),
#    (0.091723494, 'fire'),
#    (0.06663523, 'letter'),
#    (0.057696626, 'floor'),
#    (0.056374013, 'wood'),
#    (0.04691034, 'boys'),
#    (0.045807544, 'eat'),
#    (0.042166926, 'asked'),
#    (0.030052666, 'seated'),
#    (0.029655987, 'tears'),
#    (0.027283845, 'break'),
#    (0.026163213, 'lines'),
#    (0.020712145, 'may'),
#    (0.020650959, 'quarters'),
#    (0.0204333, 'pocket'),
#    (0.018096384, 'stuff'),
#    (0.0149275465, 'forming'),
#    (0.014434499, 'helped'),
#    (0.011900307, 'breathe'),
#    (0.011652722, 'leisure')],
#   -8.43852459086281),
#  ([(0.115017, 'feet'),
#    (0.07640259, 'standing'),
#    (0.06906394, 'why'),
#    (0.061776817, 'stone'),
#    (0.05953838, 'miles'),
#    (0.04738825, 'started'),
#    (0.03809256, 'woods'),
#    (0.038042057, 'walls'),
#    (0.037044976, 'valley'),
#    (0.032684885, 'enter'),
#    (0.03235422, 'space'),
#    (0.029610423, 'village'),
#    (0.02584184, 'charge'),
#    (0.024010232, 'throw'),
#    (0.023818737, 'smiled'),
#    (0.023548948, 'built'),
#    (0.023105297, 'chief'),
#    (0.02266402, 'building'),
#    (0.021809474, 'dwelling'),
#    (0.016994866, 'triumph')],
#   -8.469477630930902),
#  ([(0.25301504, 'see'),
#    (0.23097242, 'you'),
#    (0.14142907, 'now'),
#    (0.09007031, 'here'),
#    (0.05190289, 'mean'),
#    (0.032646894, 'knows'),
#    (0.022056399, 'us'),
#    (0.018476244, 'better'),
#    (0.01696536, 'we'),
#    (0.014672166, 'a'),
#    (0.014500358, 'yourself'),
#    (0.013677868, 'writing'),
#    (0.0132858, 'thank'),
#    (0.013147629, 'ourselves'),
#    (0.012838673, 'press'),
#    (0.010508074, 'yesterday'),
#    (0.007432138, 'shame'),
#    (0.0073072067, 'shoes'),
#    (0.005966563, 'hurt'),
#    (0.005748111, 'robe')],
#   -8.483854431895159),
#  ([(0.08394112, 'light'),
#    (0.08090296, 'death'),
#    (0.056292742, 'dark'),
#    (0.05105169, 'master'),
#    (0.050025906, 'show'),
#    (0.04411167, 'how'),
#    (0.041500863, 'spring'),
#    (0.040724166, 'goes'),
#    (0.03501074, 'beach'),
#    (0.029459884, 'shook'),
#    (0.027343784, 'died'),
#    (0.025860712, 'wait'),
#    (0.025739687, 'breeze'),
#    (0.025598772, 'horses'),
#    (0.022318868, 'flowers'),
#    (0.02190756, 'ring'),
#    (0.017758641, 'setting'),
#    (0.017482461, 'leading'),
#    (0.016036749, 'three'),
#    (0.01523891, 'mistress')],
#   -8.527932102805043),
#  ([(0.12158401, 'who'),
#    (0.065216236, 'book'),
#    (0.054530185, 'kings'),
#    (0.047440372, 'heaven'),
#    (0.043708093, 'mans'),
#    (0.041497935, 'dropped'),
#    (0.0408678, 'paper'),
#    (0.039872125, 'gold'),
#    (0.038375746, 'thats'),
#    (0.030722184, 'waters'),
#    (0.029078644, 'whispered'),
#    (0.028965225, 'books'),
#    (0.025556536, 'forget'),
#    (0.024671603, 'wars'),
#    (0.02402544, 'keeping'),
#    (0.022810327, 'written'),
#    (0.020839248, 'closet'),
#    (0.018022876, 'author'),
#    (0.017874693, 'pulling'),
#    (0.017783102, 'merry')],
#   -8.55963037484712),
#  ([(0.3676032, 'me'),
#    (0.10025411, 'soul'),
#    (0.059436794, 'ah'),
#    (0.04818419, 'arms'),
#    (0.034223318, 'child'),
#    (0.033475745, 'still'),
#    (0.033439457, 'mine'),
#    (0.02295414, 'according'),
#    (0.021452425, 'follow'),
#    (0.018937197, 'trust'),
#    (0.016150106, 'hence'),
#    (0.013654149, 'flying'),
#    (0.013500997, 'thanks'),
#    (0.0132822655, 'as'),
#    (0.010950899, 'honest'),
#    (0.01025927, 'custom'),
#    (0.010217171, 'existence'),
#    (0.009762063, 'accounts'),
#    (0.009263038, 'smoking'),
#    (0.009206898, 'hurrying')],
#   -8.808217201364753),
#  ([(0.15105459, 'eyes'),
#    (0.085124, 'words'),
#    (0.07650875, 'sun'),
#    (0.034047484, 'silence'),
#    (0.03365086, 'expression'),
#    (0.030769816, 'up'),
#    (0.028802617, 'grief'),
#    (0.028184563, 'pull'),
#    (0.025227983, 'bow'),
#    (0.022244435, 'exclaimed'),
#    (0.021089515, 'rain'),
#    (0.020885386, 'cheek'),
#    (0.020808674, 'moved'),
#    (0.019895487, 'threw'),
#    (0.018887844, 'worlds'),
#    (0.017883448, 'advanced'),
#    (0.01600368, 'remark'),
#    (0.015097334, 'bowed'),
#    (0.014838555, 'catching'),
#    (0.013886509, 'could')],
#   -9.092847251422999),
#  ([(0.07754549, 'body'),
#    (0.04996268, 'living'),
#    (0.044304296, 'money'),
#    (0.042655636, 'blood'),
#    (0.039777298, 'law'),
#    (0.03519311, 'race'),
#    (0.03484659, 'dead'),
#    (0.032837786, 'wise'),
#    (0.032357838, 'port'),
#    (0.031582072, 'laid'),
#    (0.0301092, 'drop'),
#    (0.027882712, 'lived'),
#    (0.0251806, 'cry'),
#    (0.02136638, 'gives'),
#    (0.02043031, 'deep'),
#    (0.016489014, 'moon'),
#    (0.013595269, 'buy'),
#    (0.013519033, 'breathed'),
#    (0.013445601, 'shadow'),
#    (0.012900543, 'reality')],
#   -9.240150993044693),
#  ([(0.24106948, 'things'),
#    (0.09726909, 'seems'),
#    (0.05629038, 'officers'),
#    (0.05541696, 'long'),
#    (0.052313846, 'good'),
#    (0.04111854, 'strangers'),
#    (0.03991544, 'youth'),
#    (0.030422335, 'learn'),
#    (0.023747977, 'morrow'),
#    (0.0230588, 'hate'),
#    (0.022888234, 'ways'),
#    (0.022604205, 'also'),
#    (0.020507615, 'failed'),
#    (0.019844154, 'winter'),
#    (0.016805232, 'cheerfulness'),
#    (0.015394844, 'encountered'),
#    (0.013957956, 'ordered'),
#    (0.012474354, 'laws'),
#    (0.012323342, 'pursuit'),
#    (0.009726947, 'fair')],
#   -9.29052261332687),
#  ([(0.06800837, 'war'),
#    (0.06772044, 'ships'),
#    (0.06687013, 'board'),
#    (0.0664639, 'in'),
#    (0.050091755, 'wine'),
#    (0.04575614, 'by'),
#    (0.040032387, 'run'),
#    (0.04001808, 'officer'),
#    (0.03407808, 'prove'),
#    (0.031208554, 'hearts'),
#    (0.0223638, 'example'),
#    (0.020417837, 'creatures'),
#    (0.019991059, 'plenty'),
#    (0.019206295, 'poor'),
#    (0.019021098, 'damp'),
#    (0.018212492, 'bottle'),
#    (0.017974805, 'fill'),
#    (0.017676156, 'shaking'),
#    (0.016039845, 'aye'),
#    (0.015812645, 'authority')],
#   -9.363814680829371),
#  ([(0.08399754, 'boat'),
#    (0.044513308, 'mouth'),
#    (0.03696919, 'shore'),
#    (0.03605904, 'ha'),
#    (0.0328852, 'sides'),
#    (0.031477608, 'cast'),
#    (0.027114883, 'hundred'),
#    (0.023226952, 'forced'),
#    (0.021126151, 'guard'),
#    (0.02039226, 'conceit'),
#    (0.020050239, 'devil'),
#    (0.019647675, 'escape'),
#    (0.016323375, 'surface'),
#    (0.016203888, 'strike'),
#    (0.015883874, 'above'),
#    (0.015378257, 'stock'),
#    (0.0148165915, 'same'),
#    (0.014651012, 'bone'),
#    (0.014282649, 'wreck'),
#    (0.014238976, 'stage')],
#   -9.58660448436953),
#  ([(0.1081121, 'help'),
#    (0.057283115, 'bound'),
#    (0.056481134, 'try'),
#    (0.054330077, 'wont'),
#    (0.05046359, 'while'),
#    (0.043955445, 'another'),
#    (0.038499363, 'lives'),
#    (0.033444613, 'laugh'),
#    (0.033321816, 'fields'),
#    (0.03264906, 'condition'),
#    (0.03138141, 'picture'),
#    (0.02916357, 'remains'),
#    (0.024588933, 'peculiar'),
#    (0.0186377, 'poet'),
#    (0.01792893, 'earnest'),
#    (0.017728316, 'sunk'),
#    (0.01748656, 'despair'),
#    (0.017386207, 'surprised'),
#    (0.015324819, 'remove'),
#    (0.015288789, 'attached')],
#   -9.979803715437976),
#  ([(0.19293743, 'there'),
#    (0.13335027, 'oh'),
#    (0.048552804, 'watch'),
#    (0.0468776, 'quarter'),
#    (0.040890582, 'sake'),
#    (0.03456158, 'answered'),
#    (0.03249556, 'heavens'),
#    (0.029414829, 'upon'),
#    (0.02669724, 'blow'),
#    (0.025086671, 'twelve'),
#    (0.024115488, 'these'),
#    (0.02027286, 'sometimes'),
#    (0.020199278, 'midnight'),
#    (0.019925442, 'showing'),
#    (0.018169034, 'darkness'),
#    (0.017434608, 'distrust'),
#    (0.015558898, 'at'),
#    (0.015230512, 'along'),
#    (0.014085557, 'grove'),
#    (0.012341341, 'stole')],
#   -10.129636336405778),
#  ([(0.28788581, 'then'),
#    (0.09535012, 'myself'),
#    (0.06829193, 'dear'),
#    (0.0660437, 'though'),
#    (0.06447674, 'will'),
#    (0.04891834, 'ten'),
#    (0.044953834, 'doctor'),
#    (0.03225517, 'true'),
#    (0.027871514, 'paid'),
#    (0.026779462, 'silver'),
#    (0.024372289, 'begin'),
#    (0.02273312, 'glad'),
#    (0.020339778, 'sword'),
#    (0.019401845, 'alone'),
#    (0.018314287, 'trying'),
#    (0.013398917, 'mornings'),
#    (0.011319486, 'resigned'),
#    (0.009495136, 'bye'),
#    (0.008774965, 'tis'),
#    (0.008405085, 'corpse')],
#   -10.335278029605414),
#  ([(0.14948446, 'boy'),
#    (0.1072892, 'lord'),
#    (0.04609976, 'aspect'),
#    (0.043702647, 'tree'),
#    (0.042893544, 'bottom'),
#    (0.037640963, 'beneath'),
#    (0.033823114, 'gazed'),
#    (0.031608626, 'touched'),
#    (0.026961692, 'buried'),
#    (0.021899866, 'sprang'),
#    (0.01996024, 'orders'),
#    (0.019641172, 'forever'),
#    (0.018767657, 'certain'),
#    (0.017598014, 'mansion'),
#    (0.017155593, 'old'),
#    (0.016703581, 'black'),
#    (0.0137225855, 'suspended'),
#    (0.012991802, 'patient'),
#    (0.012933792, 'containing'),
#    (0.01203122, 'wore')],
#   -10.401837691567653),
#  ([(0.20405504, 'go'),
#    (0.17458926, 'let'),
#    (0.15140177, 'cried'),
#    (0.0980812, 'box'),
#    (0.072442375, 'ye'),
#    (0.050541613, 'fellow'),
#    (0.030167066, 'bread'),
#    (0.02973041, 'off'),
#    (0.022659184, 'hearted'),
#    (0.016935196, 'fool'),
#    (0.015678447, 'broke'),
#    (0.013125703, 'behind'),
#    (0.011166525, 'darted'),
#    (0.01072151, 'wrong'),
#    (0.010242244, 'turns'),
#    (0.0092140725, 'contempt'),
#    (0.0091946805, 'whatever'),
#    (0.007519455, 'accident'),
#    (0.007108314, 'gate'),
#    (0.0048754713, 'losing')],
#   -10.711589915353581),
#  ([(0.06884543, 'coat'),
#    (0.060616843, 'guide'),
#    (0.04984557, 'pay'),
#    (0.046533566, 'pride'),
#    (0.04583711, 'ask'),
#    (0.04361836, 'gun'),
#    (0.027239751, 'assure'),
#    (0.025770877, 'imagine'),
#    (0.02510428, 'match'),
#    (0.02420035, 'disdain'),
#    (0.024004884, 'thinks'),
#    (0.02266824, 'sure'),
#    (0.021453377, 'shall'),
#    (0.02104181, 'angel'),
#    (0.02025157, 'understanding'),
#    (0.01875563, 'questions'),
#    (0.01776225, 'happen'),
#    (0.017636642, 'pockets'),
#    (0.017160501, 'respects'),
#    (0.016720818, 'rule')],
#   -10.80186676331074),
#  ([(0.07032177, 'read'),
#    (0.0592268, 'vain'),
#    (0.042989705, 'following'),
#    (0.036434036, 'wall'),
#    (0.034767125, 'note'),
#    (0.034507364, 'over'),
#    (0.031705942, 'aunt'),
#    (0.030743543, 'reading'),
#    (0.029163305, 'broken'),
#    (0.025669333, 'office'),
#    (0.021580214, 'ball'),
#    (0.020646753, 'steps'),
#    (0.020285865, 'emotions'),
#    (0.01952503, 'start'),
#    (0.01903874, 'title'),
#    (0.018539017, 'demanded'),
#    (0.016689677, 'coach'),
#    (0.016662741, 'hereafter'),
#    (0.016448934, 'language'),
#    (0.01586882, 'without')],
#   -10.970168951954841),
#  ([(0.1789014, 'more'),
#    (0.11199857, 'hold'),
#    (0.07744769, 'out'),
#    (0.042099096, 'first'),
#    (0.034367923, 'experience'),
#    (0.032795433, 'hinted'),
#    (0.031523913, 'somehow'),
#    (0.027179165, 'lead'),
#    (0.02599771, 'birds'),
#    (0.024240844, 'tongue'),
#    (0.022633446, 'declared'),
#    (0.020630172, 'takes'),
#    (0.02050242, 'wear'),
#    (0.019470764, 'sighed'),
#    (0.019079525, 'subjects'),
#    (0.015337643, 'killed'),
#    (0.0144257415, 'singing'),
#    (0.0143579235, 'insight'),
#    (0.014153417, 'altogether'),
#    (0.013597712, 'sport')],
#   -11.018816992564753),
#  ([(0.05857739, 'order'),
#    (0.05295437, 'sailor'),
#    (0.035312284, 'grave'),
#    (0.034063704, 'behold'),
#    (0.034040954, 'memory'),
#    (0.03395644, 'cases'),
#    (0.032917112, 'humanity'),
#    (0.032724906, 'presence'),
#    (0.03232971, 'bit'),
#    (0.026496565, 'meal'),
#    (0.024409795, 'beings'),
#    (0.0239833, 'stream'),
#    (0.02378008, 'paused'),
#    (0.016609794, 'study'),
#    (0.014661711, 'bows'),
#    (0.014104351, 'guests'),
#    (0.014064702, 'rude'),
#    (0.014046791, 'adjoining'),
#    (0.013420304, 'theirs'),
#    (0.013197951, 'vault')],
#   -11.031708471622062),
#  ([(0.13492411, 'name'),
#    (0.081158735, 'none'),
#    (0.03356963, 'mentioned'),
#    (0.03290275, 'deemed'),
#    (0.030818515, 'lies'),
#    (0.02651799, 'ends'),
#    (0.025083005, 'names'),
#    (0.023536973, 'faith'),
#    (0.020835152, 'silent'),
#    (0.020013524, 'practice'),
#    (0.019939346, 'circle'),
#    (0.019845957, 'terms'),
#    (0.019135155, 'move'),
#    (0.017112544, 'sounds'),
#    (0.0166207, 'declare'),
#    (0.016320925, 'success'),
#    (0.016119694, 'recommended'),
#    (0.015110759, 'roses'),
#    (0.015064907, 'admire'),
#    (0.014771954, 'amazement')],
#   -11.351441618452892),
#  ([(0.10697531, 'sense'),
#    (0.061280556, 'crowd'),
#    (0.058500435, 'women'),
#    (0.047529478, 'spread'),
#    (0.04507775, 'strange'),
#    (0.03482156, 'advice'),
#    (0.030851977, 'alas'),
#    (0.023500906, 'streets'),
#    (0.021792809, 'harm'),
#    (0.021274699, 'report'),
#    (0.021264512, 'laughing'),
#    (0.021187454, 'seldom'),
#    (0.021153623, 'throat'),
#    (0.019752476, 'keeps'),
#    (0.019561354, 'bred'),
#    (0.019048465, 'imagined'),
#    (0.018480968, 'supposing'),
#    (0.01712953, 'dancing'),
#    (0.016349092, 'worth'),
#    (0.016343104, 'notion')],
#   -11.99149817474806),
#  ([(0.1171334, 'half'),
#    (0.06338139, 'charity'),
#    (0.061814185, 'form'),
#    (0.04124405, 'seek'),
#    (0.03787425, 'served'),
#    (0.035559252, 'frigate'),
#    (0.030938003, 'pity'),
#    (0.02894755, 'headed'),
#    (0.026019182, 'employed'),
#    (0.019506766, 'enemy'),
#    (0.019385755, 'motive'),
#    (0.018966602, 'melancholy'),
#    (0.018213075, 'flag'),
#    (0.017801685, 'ages'),
#    (0.017265253, 'action'),
#    (0.017213004, 'never'),
#    (0.017158698, 'blind'),
#    (0.016380042, 'green'),
#    (0.016200636, 'pains'),
#    (0.015078829, 'cheer')],
#   -12.915351827752179),
#  ([(0.122067064, 'captain'),
#    (0.09376609, 'story'),
#    (0.05621613, 'teeth'),
#    (0.049441557, 'mention'),
#    (0.031012103, 'philosophy'),
#    (0.027966099, 'bell'),
#    (0.023960827, 'ago'),
#    (0.023581931, 'conscience'),
#    (0.02306414, 'masters'),
#    (0.02271404, 'measure'),
#    (0.021870889, 'quality'),
#    (0.02169368, 'suffer'),
#    (0.021155966, 'complexion'),
#    (0.02108757, 'skin'),
#    (0.020952277, 'brave'),
#    (0.02034307, 'ride'),
#    (0.020124162, 'bright'),
#    (0.017703181, 'sink'),
#    (0.017445318, 'estate'),
#    (0.016412668, 'apply')],
#   -13.368022421980386)]

# %%
# pd.DataFrame(top_topics)

# %%
avg_topic_coherence = sum([t[1] for t in top_topics]) / num_topics
print(f'Average topic coherence: {round(avg_topic_coherence, 3)}.')
# Out:
# Average topic coherence: -8.654.

# %% [markdown]
# # Top Topics

# %%
TOPICS = pd.DataFrame(
    [(i, j, topic[1], *reversed(term_pair)) for i, topic in enumerate(top_topics) for j, term_pair in enumerate(topic[0])], 
    columns=['topic_id', 'term_rank', 'll', 'term_str', 'term_weight']).set_index(['topic_id','term_rank'])\
    .term_str.unstack().apply(lambda x: ' '.join(x), axis=1).to_frame('top_terms')

# %%
TOPICS['coherence'] = pd.DataFrame(top_topics)[1]

# %%
TOPICS.sort_values('coherence', ascending=False)
# Out:
#                                                   top_terms  coherence
# topic_id
# 0         was had were be been him time did being have s...  -2.173556
# 1         is be have are man it do has say know men come...  -2.394659
# 2         day came went morning till days home country c...  -3.138070
# 3         room looking stood door sat table chimney down...  -3.979811
# 4         fell back hair wind art length cut sound cant ...  -5.761031
# 5         head air face looked last hat gentlemen heads ...  -6.252651
# 6         sea round water stranger line spot trees horse...  -7.258234
# 7         years wife work age city purpose carried owing...  -7.451768
# 8         so but tell well not hear he voice suppose tal...  -7.653225
# 9         night going get no away walk stop drink yard f...  -7.914956
# 10        sight plain earth foot rose distance road top ...  -8.095219
# 11        hand eye lay mystery play throwing wisdom summ...  -8.148260
# 12        hands held forth self shot peace mark whence t...  -8.149598
# 13        ship uncle land comes says what remember ones ...  -8.231361
# 14        word gentleman turn on right the fear his save...  -8.299965
# 15        said am i sir yes turning replied wish want pr...  -8.381973
# 16        stand fire letter floor wood boys eat asked se...  -8.438525
# 17        feet standing why stone miles started woods wa...  -8.469478
# 18        see you now here mean knows us better we a you...  -8.483854
# 19        light death dark master show how spring goes b...  -8.527932
# 20        who book kings heaven mans dropped paper gold ...  -8.559630
# 21        me soul ah arms child still mine according fol...  -8.808217
# 22        eyes words sun silence expression up grief pul...  -9.092847
# 23        body living money blood law race dead wise por...  -9.240151
# 24        things seems officers long good strangers yout...  -9.290523
# 25        war ships board in wine by run officer prove h...  -9.363815
# 26        boat mouth shore ha sides cast hundred forced ...  -9.586604
# 27        help bound try wont while another lives laugh ...  -9.979804
# 28        there oh watch quarter sake answered heavens u... -10.129636
# 29        then myself dear though will ten doctor true p... -10.335278
# 30        boy lord aspect tree bottom beneath gazed touc... -10.401838
# 31        go let cried box ye fellow bread off hearted f... -10.711590
# 32        coat guide pay pride ask gun assure imagine ma... -10.801867
# 33        read vain following wall note over aunt readin... -10.970169
# 34        more hold out first experience hinted somehow ... -11.018817
# 35        order sailor grave behold memory cases humanit... -11.031708
# 36        name none mentioned deemed lies ends names fai... -11.351442
# 37        sense crowd women spread strange advice alas s... -11.991498
# 38        half charity form seek served frigate pity hea... -12.915352
# 39        captain story teeth mention philosophy bell ag... -13.368022
